# %% [markdown]
# ### Note
#     * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
student_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# 3                 67          58
# 4                 97          84
# ...              ...         ...
# 39165             99          90
# 39166             95          70
# 39167             73          84
# 39168             99          90
# 39169             95          75
#
# [39170 rows x 7 columns]

# %%
#Calculate the total number of schools
totalsch_cnt = len(school_data_complete['school_name'].unique())
totalsch_cnt
# Out:
# 15

# %%
#Calculate the total number of students
totalstu_cnt = school_data_complete['Student ID'].count()
totalstu_cnt
# Out:
# 39170

# %%
#Calculate the total budget
totalbud_cnt = school_data['budget'].sum()
totalbud_cnt
# Out:
# 24649428

# %%
#Calculate the average math score
avgdist_math = school_data_complete['math_score'].mean(axis=0)
avgdist_math
# Out:
# 78.98537145774827

# %%
#Calculate the average reading score
avgdist_reading = school_data_complete['reading_score'].mean(axis=0)
avgdist_reading
# Out:
# 81.87784018381414

# %%
#Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
overall_avg = df[["reading_score","math_score"]].mean(axis=0).mean()
overall_avg
# Out:
# 80.43160582078121

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
# mathpass_pct = ((student_data["passing_math"]).mean())*100
passing_math_cnt = len(student_data[student_data['math_score'] >= 70])
percent_passing_math = passing_math_cnt/len(student_data)*100
percent_passing_math
# Out:
# 74.9808526933878

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
passing_reading_cnt = len(student_data[student_data['reading_score'] >= 70])
percent_passing_reading = passing_reading_cnt/len(student_data)*100
percent_passing_reading
# Out:
# 85.80546336482001

# %%
#Create a dataframe to hold the above results
#Optional: give the displayed data cleaner formatting
district_all = [{"Total Schools": totalsch_cnt, 
            "Total Students": totalstu_cnt, 
            "Total Budget": totalbud_cnt, 
            "Average Math Score":  round(avgdist_math,2), 
            "Average Reading Score":  round(avgdist_reading,2), 
           "% Passing Math": round(percent_passing_math,2),
           "% Passing Reading": round(percent_passing_reading,2),
            "% Overall Passing Rate": round(overall_avg,2)}]
district_summary_table = pd.DataFrame(district_all)
#Show the table
district_summary_table
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428               78.99
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0                  81.88           74.98              85.81
#
#    % Overall Passing Rate
# 0                   80.43

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
# * Create a dataframe to hold the above results

# %%
school_data_complete["passing_math"] = school_data_complete["math_score"] >= 70
school_data_complete["passing_reading"] = school_data_complete["reading_score"] >= 70

# %%
school_group = school_data_complete.groupby(["school_name"]).mean()
school_group["Per Student Budget"] = school_group["budget"]/school_group["size"]
school_group["% Passing Math"] = round(school_group["passing_math"]*100,2)
school_group["% Passing Reading"] = round(school_group["passing_reading"]*100,2)
school_group["% Overall Passing Rate"] = round(((school_group["passing_math"] + school_group["passing_reading"])/2)*100,3)
school_group
# Out:
#                        Student ID  reading_score  math_score  School ID  \
# school_name
# Bailey High School        20358.5      81.033963   77.048432        7.0
# Cabrera High School       16941.5      83.975780   83.061895        6.0
# Figueroa High School       4391.0      81.158020   76.711767        1.0
# Ford High School          36165.0      80.746258   77.102592       13.0
# Griffin High School       12995.5      83.816757   83.351499        4.0
# Hernandez High School      9944.0      80.934412   77.289752        3.0
# Holden High School        23060.0      83.814988   83.803279        8.0
# Huang High School          1458.0      81.182722   76.629414        0.0
# Johnson High School       32415.0      80.966394   77.072464       12.0
# Pena High School          23754.5      84.044699   83.839917        9.0
# Rodriguez High School     28035.0      80.744686   76.842711       11.0
# Shelton High School        6746.0      83.725724   83.359455        2.0
# Thomas High School        38352.0      83.848930   83.418349       14.0
# Wilson High School        14871.0      83.989488   83.274201        5.0
# Wright High School        25135.5      83.955000   83.682222       10.0
#
#                          size     budget  passing_math  passing_reading  \
# school_name
# Bailey High School     4976.0  3124928.0      0.666801         0.819333
# Cabrera High School    1858.0  1081356.0      0.941335         0.970398
# Figueroa High School   2949.0  1884411.0      0.659885         0.807392
# Ford High School       2739.0  1763916.0      0.683096         0.792990
# Griffin High School    1468.0   917500.0      0.933924         0.971390
# Hernandez High School  4635.0  3022020.0      0.667530         0.808630
# Holden High School      427.0   248087.0      0.925059         0.962529
# Huang High School      2917.0  1910635.0      0.656839         0.813164
# Johnson High School    4761.0  3094650.0      0.660576         0.812224
# Pena High School        962.0   585858.0      0.945946         0.959459
# Rodriguez High School  3999.0  2547363.0      0.663666         0.802201
# Shelton High School    1761.0  1056600.0      0.938671         0.958546
# Thomas High School     1635.0  1043130.0      0.932722         0.973089
# Wilson High School     2283.0  1319574.0      0.938677         0.965396
# Wright High School     1800.0  1049400.0      0.933333         0.966111
#
#                        Per Student Budget  % Passing Math  % Passing Reading  \
# school_name
# Bailey High School                  628.0           66.68              81.93
# Cabrera High School                 582.0           94.13              97.04
